# %% [markdown]
# <a href="https://colab.research.google.com/github/scaballero1018/programacion1/blob/main/piton1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESTRUCTURA DE DATOS EN PYTHON /concatenar es pegar palabras

# %%
2*3
# Out:
# 6

# %%
print(2+3)
# Out:
# 5

# %%
type(3.5)
# Out:
# float

# %%
3257/82
# Out:
# 39.71951219512195

# %%
3257/82 # divisor
# Out:
# 39.71951219512195

# %%
3257/82 # Cociente
# Out:
# 39.71951219512195

# %%
2**(1/2)
# Out:
# 1.4142135623730951

# %%
edad=19
type(edad)
# Out:
# int

# %%
peso=60.7
type(peso)
# Out:
# float

# %%
numero_complejo=3+4j
type(numero_complejonumero_complejo)
# Out:
# complex

# %%
numero_complejo**2
# Out:
# (-7+24j)

# %%
es_mayor=true

# %%
valor_desconocido=None
print(valor_desconocido,type(valor_desconocido))
# Out:
# None <class 'NoneType'>

# %%
x=66

# %%
x*2
# Out:
# 132

# %% [markdown]
# Cadenas se pueden escribir en comllas simples o dobles y sirven como rutas

# %%
print("viva el pan.\nviva la leche")
# Out:
# viva el pan.
# viva la leche

# %%
comprar="comprar"
vacia=" "
un="un"
restaurante="restaurante"
deseo= comprar + vacia + un + vacia + restaurante
print(deseo)
# Out:
# comprar un restaurante

# %%
print(comprar*3)
# Out:
# comprarcomprarcomprar

# %%
texto = [0]

# %%
palabra = "matematicas" #no imprime el ultimo indice, sino el penultio, pero si toma al que sale
print(palabra)
palabra [:-5]
# Out:
# matematicas
# 'matema'

# %%
palabra [11:]
# Out:
# ''

# %% [markdown]
# concatetacion es unir dos listas

# %% [markdown]
# las listas no son inmutables

# %%
cubos=[1,8,27,65,125] # hay algo mal aqui, el cubo de 4 es 64, no 65!

# %%
cubos[-2]=64 # remplazar el valor incorrecto
print(cubos)
# Out:
# [1, 8, 27, 64, 125]

# %%
cubos.append(6**3)
print(cubos)
# Out:
# [1, 8, 27, 64, 125, 216]

# %%
letras = ["a", "b", "c", "d", "e", "f"]

# %%
letras[2:5] = ["C","D","E"] # remplazar algunos valores
letras
# Out:
# ['a', 'b', 'C', 'D', 'E', 'f']

# %%
letras [2:5] = [] # tambien se pueden borras elementos
letras
# Out:
# ['a', 'b', 'f']

# %% [markdown]
# las listas permiten el anidamiento, es decir, crear

# %%
a=["a","b","c"]
n=[1,2,3]
x=[a,n,5]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3], 5]

# %%
x[0]
# Out:
# ['a', 'b', 'c']

# %%
x[1][2]
# Out:
# 3

# %%
i=256*256
print("el valor de i es",i)
# Out:
# el valor de i es 65536

# %% [markdown]
# tuplas son     inmutables ()

# %%
colores = ("rojo","verde","azul")
colores
# Out:
# ('rojo', 'verde', 'azul')

# %%
cadena=("hola mundo")
print(cadena)
# Out:
# hola mundo

# %%
lista=["h","o","l","a","","m","u","n","d","o"]
print(lista)
# Out:
# ['h', 'o', 'l', 'a', '', 'm', 'u', 'n', 'd', 'o']

# %%
tupla=("h","o","l","a","","m","u","n","d","o")

# %%
print(cadena,lista,tupla)
# Out:
# hola mundo ['h', 'o', 'l', 'a', '', 'm', 'u', 'n', 'd', 'o'] ('h', 'o', 'l', 'a', '', 'm', 'u', 'n', 'd', 'o')

# %% [markdown]
# los diccionarios guardan elementos el parejas teniendo una clave

# %%
alumno={
    "nombre":"juan",
    "edad":"18",
    "curso": "4 año",
    "altura":"1,70m"

}
print(alumno)
# Out:
# {'nombre': 'juan', 'edad': '18', 'curso': '4 año', 'altura': '1,70m'}

# %%
alumno["edad"]
# Out:
# '18'

# %%
del alumno['altura'] # para eleminar
alumno
# Out:
# {'nombre': 'juan', 'edad': '18', 'curso': '4 año'}

# %%
alumno["nota"]=alumno["edad"]
alumno
# Out:
# {'nombre': 'juan', 'edad': '18', 'curso': '4 año', 'nota': '18'}

# %% [markdown]
# conjuntos
# no tienen indices, es una coleccion de elementos

# %%
colores={"rojo","verde","azul"}
colores
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores1={"rojo","verde","azul","verde"}
colores1
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores==colores1
# Out:
# True

# %%
colores[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2154032454.py in <cell line: 0>()
# ----> 1 colores[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for color in colores
print(color)
# Out:
#   File "/tmp/ipython-input-873288305.py", line 1
#     for color in colores
#                         ^
# SyntaxError: expected ':'

# %%
tupla+tupla
# Out:
# ('h',
#  'o',
#  'l',
#  'a',
#  '',
#  'm',
#  'u',
#  'n',
#  'd',
#  'o',
#  'h',
#  'o',
#  'l',
#  'a',
#  '',
#  'm',
#  'u',
#  'n',
#  'd',
#  'o')

# %% [markdown]
# los diccionarios no se suman

# %%
lista2=[("nombre","ana"),("edad",20)]
diccionario=dict(lista2)
diccionario
# Out:
# {'nombre': 'ana', 'edad': 20}

# %%
lista2=["ana",20]
dict(lista2)#error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3833133539.py in <cell line: 0>()
#       1 lista2=["ana",20]
# ----> 2 dict(lista2)#error
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
lista3=["ana","luis","sofia"]
diccionario2=dict(enumerate(lista3))
diccionario2
# Out:
# {0: 'ana', 1: 'luis', 2: 'sofia'}

# %%
tupa2=

# %% [markdown]
# un diccionarios se puede combertir en una lista pero solo con las claves para obtener la claves se utiliza la funccion valus

# %%
alumno5 = {"nombre":"ana","edad":20,"año":"4 año"}

# %% [markdown]
# apend agrega un elemento a una tupla

# %% [markdown]
# items nos crea en listas , nos devuelebe la dupla valor,clave valor de un diccionario y son tuplas

# %% [markdown]
# set objeto conviente un objeto en un conjunto
# enumerate

# %%
R= 4+5j
type(R)
# Out:
# complex
