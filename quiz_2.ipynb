# %% [markdown]
# <a href="https://colab.research.google.com/github/scaballero1018/programacion1/blob/main/quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# quiz 2
# sergio andres caballero hernandez
# 2260671

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese el nombre del estudiante")
def pedir_nota():
  n1= float(input("nota 1:"))
  n2= float(input("nota 2:"))
  n3= float(input("nota 3:"))
  n4= float(input("nota 4:"))
  return n1,n2,n3,n4
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
def calcular_promedio(n1,n2,n3,n4):
  return (n1+n2+n3+n4)/4
import statistics
def media(n1,n2,n3,n4):
  return statistics.median([n1,n2,n3,n4])
def moda(n1,n2,n3,n4):
  return statistics.mode([n1,n2,n3,n4])
# Out:
# Overwriting promedio.py

# %%
import pedirnotas
nombre=pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiantejulian

# %%
import pedirnotas
importlib.reload(pedirnotas)
n=pedirnotas.pedir_nota()
# Out:
# nota 1:5
# nota 2:5
# nota 3:4
# nota 4:3

# %%
import promedio
import importlib
importlib.reload(promedio)
prom=promedio.calcular_promedio(n[0],n[1],n[2],n[3])
mediana=promedio.media(n[0],n[1],n[2],n[3])
moda=promedio.moda(n[0],n[1],n[2],n[3])
print("estudiante:",nombre)
print("En promedio el estudiante obtuvo:",prom)
print("La calificacion mas repetida es:",moda)
print("El valor que divide el 50% de las calificaciones es:",mediana)
if prom>=3:
  print("El desempeño es: aprobado")
else:
  print("El desempeño es: reprobado")
# Out:
# estudiante: julian
# En promedio el estudiante obtuvo: 4.25
# La calificacion mas repetida es: 5.0
# El valor que divide el 50% de las calificaciones es: 4.5
# El desempeño es: aprobado

# %% [markdown]
# Analisis:
#
# ---
#
#
# estudiante: julian
#
# ---
#
#
# En promedio el estudiante obtuvo: 4.25
#
# ---
#
#
# La calificacion mas repetida es: 5.0
#
# ---
#
#
# El valor que divide el 50% de las calificaciones es: 4.5
#
# ---
#
#
# El desempeño es: aprobado
