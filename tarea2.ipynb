# %% [markdown]
# <a href="https://colab.research.google.com/github/scaballero1018/programacion1/blob/main/tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# codigos del primer video

# %%
# Listas

lista = [29, True, 3.1415, "El número de Avogadro sí que mola"]

print(lista)
print(lista[-1])
print(lista[1:3])

lista[2] = "He cambiado este elemento"

lista[2] = [3, 2, 1]
print(lista)

print(len(lista))
# Out:
# [29, True, 3.1415, 'El número de Avogadro sí que mola']
# El número de Avogadro sí que mola
# [True, 3.1415]
# [29, True, [3, 2, 1], 'El número de Avogadro sí que mola']
# 4

# %%
lista_nueva = [1, 2, 3, 4, 5]

lista_nueva.append(3)

print(lista_nueva)

print(lista_nueva.count(3))

print(lista_nueva.index(4))

lista_nueva.remove(3)

print(lista_nueva)
# Out:
# [1, 2, 3, 4, 5, 3]
# 2
# 3
# [1, 2, 4, 5, 3]

# %%
# Tuplas

tupla = ("¿La tierra es plana?", True, False)
print(tupla)

print(tupla[0])
print(tupla[1])
print(tupla[2])

print(tupla.count(True))
print(tupla.index(False))

print((1))
print((1,))
# Out:
# ('¿La tierra es plana?', True, False)
# ¿La tierra es plana?
# True
# False
# 1
# 2
# 1
# (1,)

# %%
# Conjunto

print(set())

print(set([5, 2, 5, 1, 1.5]))
print(set((5, 2, 5, 1, 1.5)))
print(set("52511.5"))

conjunto = set([2, 3, 3, 4])
conjunto_2 = set([5, 3, 5, 6])
conjunto_3 = set([4, 2])

print(conjunto)
print(conjunto_2)
print(conjunto_3)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)

print(conjunto.intersection(conjunto_2))
print(conjunto_2.issubset(conjunto))
print(conjunto_3.issubset(conjunto))
# Out:
# set()
# {1, 2, 5, 1.5}
# {1, 2, 5, 1.5}
# {'.', '5', '2', '1'}
# {2, 3, 4}
# {3, 5, 6}
# {2, 4}
# {1, 2, 3, 4}
# {2, 3, 4}
# {3}
# False
# True

# %%
# Diccionario

diccionario = {1: "Uno", 2: "Dos"}
diccionario[3] = "Tres"
print(diccionario)

dict_lista_tuplas = dict([(1, "Uno"), (2, "Dos"), (3, "Tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(Uno = 1, Dos = 2, Tres = 3)
print(dict_lista_string)

dict_tipos = {1: "integer",
              2.2: "float",
              "texto": "string",
              (1, 2): "tupla"}

print(dict_tipos)

dict_repeticion = {1: "Primero", 1: "Último"}
print(dict_repeticion)

print(diccionario,
      diccionario.keys(),
      diccionario.values(),
      diccionario.items())

claves = diccionario.values()
print(claves)
diccionario[1] = "One"
print(claves)
diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'Uno', 2: 'Dos', 3: 'Tres'}
# {1: 'Uno', 2: 'Dos', 3: 'Tres'}
# {'Uno': 1, 'Dos': 2, 'Tres': 3}
# {1: 'integer', 2.2: 'float', 'texto': 'string', (1, 2): 'tupla'}
# {1: 'Último'}
# {1: 'Uno', 2: 'Dos', 3: 'Tres'} dict_keys([1, 2, 3]) dict_values(['Uno', 'Dos', 'Tres']) dict_items([(1, 'Uno'), (2, 'Dos'), (3, 'Tres')])
# dict_values(['Uno', 'Dos', 'Tres'])
# dict_values(['One', 'Dos', 'Tres'])
# {1: 'One', 3: 'Tres'}

# %% [markdown]
# codigos del segundo video

# %%
# Ejemplo de conversión de distintos tipos a False

print(0, "->", bool(0))
print(0.0, "->", bool(0.0))
print("", "->", bool(""))
print(list(), "->", bool(list()))
print(tuple(), "->", bool(tuple()))
print(set(), "->", bool(set()))
print(dict(), "->", bool(dict()))
print(None, "->", bool(None))
# Out:
# 0 -> False
# 0.0 -> False
#  -> False
# [] -> False
# () -> False
# set() -> False
# {} -> False
# None -> False

# %%
# Ejemplo de conversión de distintos tipos a True

print(9000, "->", bool(9000))
print(3.1415, "->", bool(3.1415))
print("Cadena", "->", bool("Cadena"))
print(list((1, 2)), "->", bool(list((1, 2))))
print(tuple((1, 2)), "->", bool(tuple((1, 2))))
print(set((1, 2)), "->", bool(set((1, 2))))
print(dict([(1,2)]), "->", bool(dict([(1,1)])))
# Out:
# 9000 -> True
# 3.1415 -> True
# Cadena -> True
# [1, 2] -> True
# (1, 2) -> True
# {1, 2} -> True
# {1: 2} -> True

# %%
# Ejemplo if-else

nota = float(input("Introduzca su nota: "))
if nota < 5:
  print("Estás suspenso, F")
else:
  print("Estás aprobado, ¡enhorabuena!")
# Out:
# Introduzca su nota: 9
# Estás aprobado, ¡enhorabuena!

# %%
#Ejemplo if-elif-else

nota = float(input("Introduzca su nota: "))
if 0 <= nota and nota < 5:
  print("Estás suspenso, F")
elif 5 <= nota and nota < 7:
  print("Aprobado")
elif 7 <= nota and nota < 9:
  print("Notable")
elif 9 <= nota and nota <= 10:
  print("Sobresaliente")
else:
  print("Nota fuera de rango")
# Out:
# Introduzca su nota: 2
# Estás suspenso, F

# %%
# Ejemplo while

contador = 3
while contador != 0:
  contador = contador - 1
  print("El contenido de contador es", contador)
# Out:
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %%
# Ejemplo básico del for

for iterador in [1, 2, 3]:
  print(iterador)
# Out:
# 1
# 2
# 3

# %%
# for sobre estructuras de datos

lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in lista:
  print(iterador)
# Out:
# 2
# 1
# 0

# %%
# Acceso por índices a una lista con un for

lista = ["Vamos", "a", "acceder", "a", "esta", "lista", "por", "índices"]

for indice in range(len(lista)):
  print("Indice:", indice,"Elemento:", lista[indice])
# Out:
# Indice: 0 Elemento: Vamos
# Indice: 1 Elemento: a
# Indice: 2 Elemento: acceder
# Indice: 3 Elemento: a
# Indice: 4 Elemento: esta
# Indice: 5 Elemento: lista
# Indice: 6 Elemento: por
# Indice: 7 Elemento: índices

# %%
# for para visualizar el efecto de las sentencias break y continue

for numero in range(5):
  print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Visualización del efecto de la sentencia break

for numero in range(5):
  if numero == 3:
    break
  print(numero)
# Out:
# 0
# 1
# 2

# %%
# Visualización del efecto de la sentencia continue

for numero in range(5):
  if numero == 3:
    continue
  print(numero)
# Out:
# 0
# 1
# 2
# 4

# %%
# Uso del else en un while

intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# >>> Escriba la contraseña:9
# Contraseña incorrecta
# >>> Escriba la contraseña:2
# Contraseña incorrecta
# >>> Escriba la contraseña:9
# Contraseña incorrecta
# Se te acabaron los intentos :(

# %% [markdown]
# modificando los codigos

# %% [markdown]
# primer video

# %%
# Listas

lista = [29, False, 3.1415, "El número de Avogadro sí que mola"]

print(lista)
print(lista[-0])
print(lista[1:2])

lista[2] = "r"

lista[2] = ["3, 2, 1","hola mundo "]
lista[3] = [3, 2, 1]
print(lista)

print(len(lista))
# Out:
# [29, False, 3.1415, 'El número de Avogadro sí que mola']
# 29
# [False]
# [29, False, ['3, 2, 1', 'hola mundo '], [3, 2, 1]]
# 4

# %%
lista_nueva = [1, 2, 3, 4, 5]

lista_nueva.append(6)

print(lista_nueva)

print(lista_nueva.count(3))

print(lista_nueva.index(5))

lista_nueva.remove(2)

print(lista_nueva)
# Out:
# [1, 2, 3, 4, 5, 6]
# 1
# 4
# [1, 3, 4, 5, 6]

# %%
tupla = ("¿La tierra es redonda?", True, False, True)
print(tupla)

print(tupla[0])
print(tupla[1])
print(tupla[2])
print(tupla[3])

print(tupla.count(True))
print(tupla.index(False))

print((2))
print((2,))
# Out:
# ('¿La tierra es redonda?', True, False, True)
# ¿La tierra es redonda?
# True
# False
# True
# 2
# 2
# 2
# (2,)

# %%
# Conjunto

print(set())

print(set([5, 2, 5, 1, 1.5]))
print(set((5, 2, 5, 1, 1.5)))
print(set("52511.5"))

conjunto = set([2, 3, 3, 4])
conjunto_2 = set([5, 3, 5, 6])
conjunto_3 = set([4, 2])

print(conjunto)
print(conjunto_2)
print(conjunto_3)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)

print(conjunto.union(conjunto_2))
print(conjunto.intersection(conjunto_2))

print(conjunto_2.issubset(conjunto))
print(conjunto_3.issubset(conjunto))
# Out:
# set()
# {1, 2, 5, 1.5}
# {1, 2, 5, 1.5}
# {'.', '5', '2', '1'}
# {2, 3, 4}
# {3, 5, 6}
# {2, 4}
# {1, 2, 3, 4}
# {2, 3, 4}
# {2, 3, 4, 5, 6}
# {3}
# False
# True

# %%
diccionario = {1: "Uno", 2: "Dos"}
diccionario[3] = "Tres"
diccionario[4] = "Cuatro"
print(diccionario)

dict_lista_tuplas = dict([(1, "Uno"), (2, "Dos"), (3, "Tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(Uno=1, Dos=2, Tres=3)
print(dict_lista_string)

dict_tipos = {
    1: "integer",
    2.2: "float",
    "texto": "string",
    (1, 2): "tupla"
}
print(dict_tipos)

dict_repeticion = {1: "Primero", 1: "Último"}
print(dict_repeticion)

print(diccionario)
print(diccionario.keys())
print(diccionario.values())
print(diccionario.items())

claves = diccionario.values()
print(claves)

diccionario[1] = "One"
print(claves)

diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'Uno', 2: 'Dos', 3: 'Tres', 4: 'Cuatro'}
# {1: 'Uno', 2: 'Dos', 3: 'Tres'}
# {'Uno': 1, 'Dos': 2, 'Tres': 3}
# {1: 'integer', 2.2: 'float', 'texto': 'string', (1, 2): 'tupla'}
# {1: 'Último'}
# {1: 'Uno', 2: 'Dos', 3: 'Tres', 4: 'Cuatro'}
# dict_keys([1, 2, 3, 4])
# dict_values(['Uno', 'Dos', 'Tres', 'Cuatro'])
# dict_items([(1, 'Uno'), (2, 'Dos'), (3, 'Tres'), (4, 'Cuatro')])
# dict_values(['Uno', 'Dos', 'Tres', 'Cuatro'])
# dict_values(['One', 'Dos', 'Tres', 'Cuatro'])
# {1: 'One', 3: 'Tres', 4: 'Cuatro'}

# %% [markdown]
# segundo video

# %%
# Ejemplo de conversión de distintos tipos a False

print(0, "->", bool(0))
print(1, "->", bool(1))

print(0.0, "->", bool(0.0))
print(2.5, "->", bool(2.5))

print("", "->", bool(""))
print("Hola", "->", bool("Hola"))

print(list(), "->", bool(list()))
print([1, 2], "->", bool([1, 2]))

print(tuple(), "->", bool(tuple()))
print((1,), "->", bool((1,)))

print(set(), "->", bool(set()))
print({1, 2}, "->", bool({1, 2}))

print(dict(), "->", bool(dict()))
print({"a": 1}, "->", bool({"a": 1}))

print(None, "->", bool(None))
# Out:
# 0 -> False
# 1 -> True
# 0.0 -> False
# 2.5 -> True
#  -> False
# Hola -> True
# [] -> False
# [1, 2] -> True
# () -> False
# (1,) -> True
# set() -> False
# {1, 2} -> True
# {} -> False
# {'a': 1} -> True
# None -> False

# %%
# Ejemplo de conversión de distintos tipos a True

print(9000, "->", bool(9000))
print(3.1415, "->", bool(3.1415))

print("Cadena", "->", bool("Cadena"))
print("Python", "->", bool("Python"))

print(list((1, 2)), "->", bool(list((1, 2))))
print(tuple((1, 2)), "->", bool(tuple((1, 2))))

print(set((1, 2)), "->", bool(set((1, 2))))
print(set(), "->", bool(set()))

print(dict([(1, 2)]), "->", bool(dict([(1, 2)])))
print(dict(), "->", bool(dict()))
# Out:
# 9000 -> True
# 3.1415 -> True
# Cadena -> True
# Python -> True
# [1, 2] -> True
# (1, 2) -> True
# {1, 2} -> True
# set() -> False
# {1: 2} -> True
# {} -> False

# %%
# Ejemplo if-else

nota = float(input("Introduzca su nota: "))

if nota < 3:
    print("Estás suspenso, F")
elif nota < 5:
    print("Estás en recuperación")
else:
    print("Estás aprobado, ¡enhorabuena!")
# Out:
# Introduzca su nota: 2
# Estás suspenso, F

# %%
#Ejemplo if-elif-else

nota = float(input("Introduzca su nota: "))

if nota < 0 or nota > 10:
    print("Nota fuera de rango")
elif nota < 5:
    print("Estás suspenso, F")
elif nota < 7:
    print("Aprobado")
elif nota < 9:
    print("Notable")
else:
    print("Sobresaliente")
# Out:
# Introduzca su nota: 3
# Estás suspenso, F

# %%
# Ejemplo while
contador = 3

print("Inicio del contador")

while contador != 0:
    contador = contador - 1
    print("El contenido de contador es", contador)

print("Fin del ciclo")
# Out:
# Inicio del contador
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0
# Fin del ciclo

# %%
# Acceso por índices a una lista con un for

lista = ["Vamos", "a", "acceder", "a", "esta", "lista", "por", "índices"]

print("Número de elementos:", len(lista))

for indice in range(len(lista)):
    print("Indice:", indice, "Elemento:", lista[indice])

print("Fin del recorrido")
# Out:
# Número de elementos: 8
# Indice: 0 Elemento: Vamos
# Indice: 1 Elemento: a
# Indice: 2 Elemento: acceder
# Indice: 3 Elemento: a
# Indice: 4 Elemento: esta
# Indice: 5 Elemento: lista
# Indice: 6 Elemento: por
# Indice: 7 Elemento: índices
# Fin del recorrido

# %%
# for para visualizar el efecto de las sentencias break y continue

for numero in range(5):
    print("Número:", numero)

print("Fin del ciclo")
# Out:
# Número: 0
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Fin del ciclo

# %%
# Visualización del efecto de la sentencia break

for numero in range(5):
    if numero == 3:
        print("Se detuvo el ciclo en el número", numero)
        break
    print(numero)

print("Fin del programa")
# Out:
# 0
# 1
# 2
# Se detuvo el ciclo en el número 3
# Fin del programa

# %%
# Uso del else en un while

intentos = 3

while intentos > 0:
    if input(">>> Escriba la contraseña: ") == "contraseña":
        print("¡Correcta!")
        break
    intentos = intentos - 1
    print("Contraseña incorrecta")
    print("Intentos restantes:", intentos)

else:
    print("Se te acabaron los intentos :(")
# Out:
# >>> Escriba la contraseña: contraseña
# ¡Correcta!
