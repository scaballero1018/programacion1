# %% [markdown]
# <a href="https://colab.research.google.com/github/scaballero1018/programacion1/blob/main/parcial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sergio Andres Caballero Hernandez
# 2260671

# %%
import numpy as np

# %%
a= np.array(["c","p","m","m","n"])

# %%
np.sort(a)
# Out:
# array(['c', 'm', 'm', 'n', 'p'], dtype='<U1')

# %% [markdown]
# los ordena alfabeticamente

# %%
np.unique(a)
# Out:
# array(['c', 'm', 'n', 'p'], dtype='<U1')

# %% [markdown]
# Elimina valores repetido y deja un solo valor porcada elemento

# %%
np.concatenate[(a,a)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1037/1483560930.py in <cell line: 0>()
# ----> 1 np.concatenate[(a,a)]
#
# TypeError: 'numpy._ArrayFunctionDispatcher' object is not subscriptable

# %%
np.reshape(a,(5,1))
# Out:
# array([['c'],
#        ['p'],
#        ['m'],
#        ['m'],
#        ['n']], dtype='<U1')

# %% [markdown]
# cambia la dimencion del arreglo numpy inicialmente utilizado. este caso el arreglo es de 2 filas y 4 columnas.

# %%
import pandas as pd
b_pd = pd.DataFrame(a)
b_pd
# Out:
#    0
# 0  c
# 1  p
# 2  m
# 3  m
# 4  n

# %% [markdown]
# como volver el archivo en data frame

# %%
a[a !="m"]
# Out:
# array(['c', 'p', 'n'], dtype='<U1')

# %% [markdown]
# diferentes de m

# %%
a[a=="m"]
# Out:
# array(['m', 'm'], dtype='<U1')

# %% [markdown]
# igaules a m

# %%
a[a>"n"]
# Out:
# array(['p'], dtype='<U1')

# %% [markdown]
# a[a>n]

# %% [markdown]
# como se hace la suma de matrices en numpy

# %% [markdown]
# el producto de adamar [elemento a elemento]

# %%
D=np.array([[1,3],[4,5]])
C=np.array([[24,6],[3,9]])
D*C
# Out:
# array([[24, 18],
#        [12, 45]])

# %%
m=np.array([D,C])
m
# Out:
# array([[[ 1,  3],
#         [ 4,  5]],
#
#        [[24,  6],
#         [ 3,  9]]])

# %%
m*D
# Out:
# array([[[ 1,  9],
#         [16, 25]],
#
#        [[24, 18],
#         [12, 45]]])

# %%
import pandas as pd
df= pd.DataFrame({
    "nombre":["ana","camilo","carlos"],
    "edad": [23,25,27],
    "nota":[4,4.5,5]
})
df
# Out:
#    nombre  edad  nota
# 0     ana    23   4.0
# 1  camilo    25   4.5
# 2  carlos    27   5.0

# %%
df["edad"]
# Out:
# 0    23
# 1    25
# 2    27
# Name: edad, dtype: int64

# %%
df.iloc[2]
# Out:
# nombre    carlos
# edad          27
# nota         5.0
# Name: 2, dtype: object

# %%
df.loc[0]
# Out:
# nombre    ana
# edad       23
# nota      4.0
# Name: 0, dtype: object

# %%
df.loc[2]
# Out:
# nombre    carlos
# edad          27
# nota         5.0
# Name: 2, dtype: object

# %%
df.loc[df["nombre"]=="carlos"]
# Out:
#    nombre  edad  nota
# 2  carlos    27   5.0

# %%
df.loc[df['edad']>23]
# Out:
#    nombre  edad  nota
# 1  camilo    25   4.5
# 2  carlos    27   5.0

# %% [markdown]
# el promedio de edades

# %%
df.sum()
# Out:
# nombre    anacamilocarlos
# edad                   75
# nota                 13.5
# dtype: object

# %% [markdown]
# el metodo sumas concadena cadena
# y la edad total de las letras

# %%
df[['edad', 'nota']].mean()
# Out:
# edad    25.0
# nota     4.5
# dtype: float64

# %%
df.min()
# Out:
# nombre    ana
# edad       23
# nota      4.0
# dtype: object

# %% [markdown]
# la salida es la palabra por el orden alfabetic. y para numeros son los valores minimos

# %%
df.max()
# Out:
# nombre    carlos
# edad          27
# nota         5.0
# dtype: object

# %%
df.describe()
# Out:
#        edad  nota
# count   3.0  3.00
# mean   25.0  4.50
# std     2.0  0.50
# min    23.0  4.00
# 25%    24.0  4.25
# 50%    25.0  4.50
# 75%    26.0  4.75
# max    27.0  5.00

# %% [markdown]
# ver como se describe

# %% [markdown]
# punto del parcia es funcio lambda

# %%
df["edad"].apply(lambda x: x+1)
# Out:
# 0    24
# 1    26
# 2    28
# Name: edad, dtype: int64

# %% [markdown]
# sumarle 1 ala edad

# %% [markdown]
# proyectos

# %%
import numpy as np
import pandas as pd
np.random.seed(123)#para guardar la semilla

# %%
datos= np.random.normal(loc=4.0, scale=0.5,size=50)#simula loc= ala media scale=es la desviacion estandar 0.5
df=pd.DataFrame({
    "nota":datos
})

# %%
df.describe()
# Out:
#             nota
# count  50.000000
# mean    4.006636
# std     0.600850
# min     2.600705
# 25%     3.610503
# 50%     3.941306
# 75%     4.461187
# max     5.196183

# %% [markdown]
# std es la desvidacion estandar

# %%
media=df["nota"].mean()

# %%
import matplotlib.pyplot as plt

df["nota"].hist()
plt.title("Histogram of Notas")
plt.xlabel("Nota Value")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import numpy as np

# Get the data
notas = df["nota"]

# Create a figure and axes
plt.figure(figsize=(10, 6))

# Plot histogram and KDE using seaborn
sns.histplot(notas, kde=True, stat="density", color="skyblue", label="Histograma y KDE")

# Fit a normal distribution to the data
mu, std = norm.fit(notas)

# Plot the PDF of the fitted normal distribution
x = np.linspace(notas.min(), notas.max(), 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r--', linewidth=2, label=f'Ajuste Normal ($\mu$={mu:.2f}, $\sigma$={std:.2f})')

# Add titles and labels for a 'bonito' plot
plt.title('Distribución de Notas con KDE y Ajuste Normal', fontsize=16)
plt.xlabel('Valor de Nota', fontsize=12)
plt.ylabel('Densidad', fontsize=12)
plt.legend(fontsize=10)
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\s'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1037/3399923064.py:21: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(x, p, 'r--', linewidth=2, label=f'Ajuste Normal ($\mu$={mu:.2f}, $\sigma$={std:.2f})')
# /tmp/ipykernel_1037/3399923064.py:21: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, p, 'r--', linewidth=2, label=f'Ajuste Normal ($\mu$={mu:.2f}, $\sigma$={std:.2f})')

# %%
from scipy.stats import shapiro
shapiro(df["nota"])
# Out:
# ShapiroResult(statistic=np.float64(0.9850592402574303), pvalue=np.float64(0.7741499006415689))

# %% [markdown]
# como el valor p es mayor que 0.05, no se rechaza la hipotesis de la  normalidad

# %% [markdown]
# si fuera menor que 0.05 se rechaza la hipotesis de normalidad

# %%
import numpy as np
import pandas as pd

np.random.seed(123)

grupo_A = np.random.normal(loc=4.0, scale=0.4, size=40)
grupo_B = np.random.normal(loc=4.3, scale=0.5, size=40)

df = pd.DataFrame({
    "A": grupo_A,
    "B": grupo_B
})

# %%
from scipy import stats
t_stat, p_val = stats.ttest_ind(df["A"], df["B"])

print("Estadístico t:", t_stat)
print("Valor p:", p_val)
# Out:
# Estadístico t: -3.350606843435094
# Valor p: 0.0012449635545749276

# %% [markdown]
# como los valores de p son menores de 0.05 se rechaza la hipotesis de la normal con una confianza del 95%

# %% [markdown]
# Parcial 2
# Sergio Andres Caballero Hernandez
# 2260671

# %% [markdown]
# instrucion1

# %%
import numpy as np
import pandas as pd
np.random.seed(0)
datos1 = np.random.randint(143, 197, 50)
datos=pd.DataFrame({
    "datos": datos1
})

# %%
datos['datos']
# Out:
# 0     187
# 1     190
# 2     196
# 3     143
# 4     146
# 5     146
# 6     182
# 7     152
# 8     162
# 9     164
# 10    193
# 11    179
# 12    166
# 13    149
# 14    167
# 15    167
# 16    155
# 17    144
# 18    181
# 19    182
# 20    166
# 21    189
# 22    167
# 23    160
# 24    180
# 25    168
# 26    156
# 27    151
# 28    152
# 29    163
# 30    194
# 31    159
# 32    194
# 33    148
# 34    158
# 35    190
# 36    143
# 37    161
# 38    178
# 39    167
# 40    192
# 41    194
# 42    172
# 43    162
# 44    162
# 45    157
# 46    182
# 47    175
# 48    144
# 49    152
# Name: datos, dtype: int64

# %%
datos
# Out:
#     datos
# 0     187
# 1     190
# 2     196
# 3     143
# 4     146
# 5     146
# 6     182
# 7     152
# 8     162
# 9     164
# 10    193
# 11    179
# 12    166
# 13    149
# 14    167
# 15    167
# 16    155
# 17    144
# 18    181
# 19    182
# 20    166
# 21    189
# 22    167
# 23    160
# 24    180
# 25    168
# 26    156
# 27    151
# 28    152
# 29    163
# 30    194
# 31    159
# 32    194
# 33    148
# 34    158
# 35    190
# 36    143
# 37    161
# 38    178
# 39    167
# 40    192
# 41    194
# 42    172
# 43    162
# 44    162
# 45    157
# 46    182
# 47    175
# 48    144
# 49    152

# %%
datos.describe()
# Out:
#             datos
# count   50.000000
# mean   167.740000
# std     16.315524
# min    143.000000
# 25%    155.250000
# 50%    166.000000
# 75%    181.750000
# max    196.000000

# %% [markdown]
# interpretacion
# contiene 50 elementos\
# con un promedio de 167\
# con una desviacion estandar ded 16.315524\
# el minimo valor es 143.000000\
# el 25% valor es 155.250000  (el 25% mas grade po decirlo asi teniendo al 100% como el valor mas grande )\
# valor medio 166.000000\
# el 75% es 181.750000\
# y el maxiomo valor o mas grade es 	196.000000

# %%
import pandas as pd
x = pd.DataFrame(datos)
normalizar = lambda x: (x - x.mean()) / x.std()
resultado = normalizar(x)
print(resultado)
# Out:
#        datos
# 0   1.180471
# 1   1.364345
# 2   1.732093
# 3  -1.516347
# 4  -1.332473
# 5  -1.332473
# 6   0.874014
# 7  -0.964725
# 8  -0.351812
# 9  -0.229230
# 10  1.548219
# 11  0.690140
# 12 -0.106647
# 13 -1.148599
# 14 -0.045356
# 15 -0.045356
# 16 -0.780851
# 17 -1.455056
# 18  0.812723
# 19  0.874014
# 20 -0.106647
# 21  1.303053
# 22 -0.045356
# 23 -0.474395
# 24  0.751432
# 25  0.015936
# 26 -0.719560
# 27 -1.026017
# 28 -0.964725
# 29 -0.290521
# 30  1.609510
# 31 -0.535686
# 32  1.609510
# 33 -1.209891
# 34 -0.596977
# 35  1.364345
# 36 -1.516347
# 37 -0.413103
# 38  0.628849
# 39 -0.045356
# 40  1.486927
# 41  1.609510
# 42  0.261101
# 43 -0.351812
# 44 -0.351812
# 45 -0.658269
# 46  0.874014
# 47  0.444975
# 48 -1.455056
# 49 -0.964725

# %% [markdown]
# instrucion 2

# %%
import pandas as pd
df= pd.DataFrame({
    "nombre":["ana","camilo","carlos","sergio","maria"],
    "edad": [23,25,27,17,20],
    "estatura":[1.70,1.80,1.85,1.70,1.77],
    "peso":[50,70,60,55,80]
})
df
# Out:
#    nombre  edad  estatura  peso
# 0     ana    23      1.70    50
# 1  camilo    25      1.80    70
# 2  carlos    27      1.85    60
# 3  sergio    17      1.70    55
# 4   maria    20      1.77    80

# %%
df["nombre"]
# Out:
# 0       ana
# 1    camilo
# 2    carlos
# 3    sergio
# 4     maria
# Name: nombre, dtype: object

# %%
df.loc[df['edad']>23]
# Out:
#    nombre  edad  estatura  peso
# 1  camilo    25      1.80    70
# 2  carlos    27      1.85    60

# %%
grupo = df.groupby("estatura")["peso"].mean()
grupo
# Out:
# estatura
# 1.70    52.5
# 1.77    80.0
# 1.80    70.0
# 1.85    60.0
# Name: peso, dtype: float64

# %%
grupo1 = df.groupby("nombre")["edad"].mean()
grupo1
# Out:
# nombre
# ana       23.0
# camilo    25.0
# carlos    27.0
# maria     20.0
# sergio    17.0
# Name: edad, dtype: float64

# %%
from google.colab import files
import csv
datos = [
    ["Nombre", "Edad", "Estarura","Peso"],
    ["ana", 23, 1.70,50],
    ["camilo", 25, 1.80,70],
    ["carlos", 27, 1.85,60],
    ["sergio", 17, 1.70,55],
    ["maria", 20, 1.77,80]
]

with open("datos.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(datos)
files.download("datos.csv")

# %% [markdown]
# parte 3

# %% [markdown]
# proyecto

# %%
import numpy as np
import pandas as pd

np.random.seed(123)

prueba_A = np.random.normal(loc=7.2, scale=0.4, size=50)
prueba_B = np.random.gamma(shape=306, scale=0.0229, size=50)

df = pd.DataFrame({
    "A": prueba_A,
    "B": prueba_B
})

# %%
df.describe()
# Out:
#                A          B
# count  50.000000  50.000000
# mean    7.205309   7.057722
# std     0.480680   0.403559
# min     6.080564   6.376485
# 25%     6.888402   6.740939
# 50%     7.153044   7.012551
# 75%     7.568949   7.329539
# max     8.156946   8.092430

# %% [markdown]
# interpretacion
# La prueba A contiene 50 elementos\
# La prueba A tiene un promedio de 7.205309\
# La prueba A tiene desviacion estandar de 16.315524\
# La prueba A el minimo valor es 143.000000\
# La prueba A el 25% valor es 155.250000  (el 25% mas grade po decirlo asi teniendo al 100% como el valor mas grande )\
# La prueba A el valor medio 166.000000\
# La prueba A el 75% es 181.750000\
# En la prueba A el maxiomo valor o mas grade es 	196.000000

# %%
from scipy.stats import shapiro
shapiro(df["A"])
# Out:
# ShapiroResult(statistic=np.float64(0.98505924025743), pvalue=np.float64(0.774149900641557))

# %%
from scipy.stats import shapiro
shapiro(df["B"])
# Out:
# ShapiroResult(statistic=np.float64(0.9717389040641473), pvalue=np.float64(0.2720114624384205))

# %% [markdown]
# como el valor p es mayor que 0.05, no se rechaza la hipotesis de la normalidad con una confianza del 95%

# %%
from scipy import stats
stats.ttest_rel(df["A"], df["B"])
# Out:
# TtestResult(statistic=np.float64(1.729598919954534), pvalue=np.float64(0.08999751035350062), df=np.int64(49))

# %% [markdown]
# como el valor de p es mayor que 0,05 el puntaje medio de ambas pruebas es igual con una confianza del 95%

# %%
from scipy import stats
stats.kendalltau(df["A"], df["B"])
# Out:
# SignificanceResult(statistic=np.float64(0.04), pvalue=np.float64(0.6818954220320396))

# %% [markdown]
# como el valor de p es mayor que 0,05 el puntaje de las pruebas estan correlacionadas con una confianza del 95%

# %%
from scipy import stats
stats.spearmanr(df["A"], df["B"])
# Out:
# SignificanceResult(statistic=np.float64(0.07034813925570228), pvalue=np.float64(0.6273521677638413))

# %% [markdown]
# como el valor de p es mayor que 0,05 el puntaje de las pruebas estan correlacionadas con una confianza del 95%

# %%
import os
os.makedirs("comparacion", exist_ok=True)
# %%writefile comparacion/pruebat.py:
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats
prueba_A = np.random.normal(loc=7.2, scale=0.4, size=50)
prueba_B = np.random.gamma(shape=306, scale=0.0229, size=50)

np.random.seed(123)
prueba_A = np.random.normal(loc=7.2, scale=0.4, size=50)
prueba_B = np.random.gamma(shape=306, scale=0.0229, size=50)

df = pd.DataFrame({
    "A": prueba_A,
    "B": prueba_B
})
stats.ttest_rel(df["A"], df["B"])
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %% [markdown]
# self en modulos, erorres, open ryas,

# %% [markdown]
# # CREAR UN CSV:
# from google.colab import files
# import csv
# datos = [
#     ["Nombre", "Edad", "Ciudad"],
#     ["Ana", 25, "Bogotá"],
#     ["Luis", 30, "Medellín"],
#     ["Carlos", 28, "Cali"]
# ]
#
# with open("datos.csv", "w", newline="") as f:
#     writer = csv.writer(f)
#     writer.writerows(datos)
#
# files.download("datos.csv")
#
# # CREAR MODULOS Y PAQUETES:
#
# import os
# os.makedirs("op", exist_ok=True)
#
# %%writefile op/operaciones.py
#
# # FUNCION LAMBDA
# import pandas as pd
# x = [1, 2, 3, 4]
# x = pd.DataFrame(x)
# normalizar = lambda x: (x - x.mean()) / x.std()
# resultado = normalizar(x)
# print(resultado)
