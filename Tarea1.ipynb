# %% [markdown]
# <a href="https://colab.research.google.com/github/scaballero1018/programacion1/blob/main/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Diseñe y corra un código en Google Colab que: (1) Cambie una lista a un una tupla, a un diccionario y a un conjunto. (2) Similar para una tupla. (3) Similar para un diccionario. (4) Similar para un conjunto. Guarde el código en un repositorio del Github personal. Copie y pegue el link en el PDF con la parte 1.

# %% [markdown]
# 1.lista

# %%
lista = ["gato","perro","loro","peces"]
tupla= tuple(lista)
diccionario= dict(enumerate(lista))
conjunto = set(lista)

print("Lista original:", lista)
print("lista a tupla:", tupla)
print("lista a diccionario:", diccionario)
print("lista a conjunto:", conjunto)
# Out:
# Lista original: ['gato', 'perro', 'loro', 'peces']
# lista a tupla: ('gato', 'perro', 'loro', 'peces')
# lista a diccionario: {0: 'gato', 1: 'perro', 2: 'loro', 3: 'peces'}
# lista a conjunto: {'perro', 'gato', 'peces', 'loro'}

# %% [markdown]
# 2.tupla

# %%
tupla = ("h", "o", "l", "a", " ", "p", "r", "o", "f", "e")
lista = list(tupla)
diccionario = dict(enumerate(tupla))
conjunto = set(tupla)

print("Tupla original:", tupla)
print("tupla a lista:", lista)
print("tupla a diccionario:", diccionario)
print("tupla a conjunto:", conjunto)
# Out:
# Tupla original: ('h', 'o', 'l', 'a', ' ', 'p', 'r', 'o', 'f', 'e')
# tupla a lista: ['h', 'o', 'l', 'a', ' ', 'p', 'r', 'o', 'f', 'e']
# tupla a diccionario: {0: 'h', 1: 'o', 2: 'l', 3: 'a', 4: ' ', 5: 'p', 6: 'r', 7: 'o', 8: 'f', 9: 'e'}
# tupla a conjunto: {'l', 'e', 'p', 'f', 'r', 'h', 'a', 'o', ' '}

# %% [markdown]
# 3. Diccionario

# %%
diccionario = {"Nombre":"Sergio","edad":"17","estatura":"1.68m","estudia":"matematicas"}
lista = list(diccionario) #aproposito no le puse items para tener las 2 opcciones
tupla = tuple(diccionario.items())
conjunto = set(diccionario.items())

print("Diccionario original:", diccionario)
print("diccionario a lista:", lista)
print("diccionario a tupla:", tupla)
print("diccionario a conjunto:", conjunto)
# Out:
# Diccionario original: {'Nombre': 'Sergio', 'edad': '17', 'estatura': '1.68m', 'estudia': 'matematicas'}
# diccionario a lista: ['Nombre', 'edad', 'estatura', 'estudia']
# diccionario a tupla: (('Nombre', 'Sergio'), ('edad', '17'), ('estatura', '1.68m'), ('estudia', 'matematicas'))
# diccionario a conjunto: {('Nombre', 'Sergio'), ('edad', '17'), ('estatura', '1.68m'), ('estudia', 'matematicas')}

# %% [markdown]
# 4.conjunto

# %%
conjunto = {100,200,300,400,500}
lista = list(conjunto)
tupla = tuple(conjunto)
diccionario = dict(enumerate(conjunto))

print("Conjunto original:", conjunto)
print("conjunto a lista:", lista)
print("conjunto a tupla:", tupla)
print("conjunto a diccionario:", diccionario)
# Out:
# Conjunto original: {400, 100, 500, 200, 300}
# conjunto a lista: [400, 100, 500, 200, 300]
# conjunto a tupla: (400, 100, 500, 200, 300)
# conjunto a diccionario: {0: 400, 1: 100, 2: 500, 3: 200, 4: 300}

# %% [markdown]
# por si es todo en un solo codigo es que no estoy seguro

# %%
# 1. LISTA


lista = ["gato","perro","loro","peces"]
tupla = tuple(lista)
diccionario = dict(enumerate(lista))
conjunto = set(lista)

print("1. LISTA")
print("Lista original:", lista)
print("Lista a tupla:", tupla)
print("Lista a diccionario:", diccionario)
print("Lista a conjunto:", conjunto)




# 2. TUPLA


tupla = ("h", "o", "l", "a", " ", "p", "r", "o", "f", "e")
lista = list(tupla)
diccionario = dict(enumerate(tupla))
conjunto = set(tupla)

print("2. TUPLA")
print("Tupla original:", tupla)
print("Tupla a lista:", lista)
print("Tupla a diccionario:", diccionario)
print("Tupla a conjunto:", conjunto)



# 3. DICCIONARIO


diccionario = {"Nombre":"Sergio","edad":"17","estatura":"1.68m","estudia":"matematicas"}
lista = list(diccionario)  # solo claves
tupla = tuple(diccionario.items())
conjunto = set(diccionario.items())

print("3. DICCIONARIO")
print("Diccionario original:", diccionario)
print("Diccionario a lista (claves):", lista)
print("Diccionario a tupla:", tupla)
print("Diccionario a conjunto:", conjunto)



# 4. CONJUNTO


conjunto = {100,200,300,400,500}
lista = list(conjunto)
tupla = tuple(conjunto)
diccionario = dict(enumerate(conjunto))

print("4. CONJUNTO")
print("Conjunto original:", conjunto)
print("Conjunto a lista:", lista)
print("Conjunto a tupla:", tupla)
print("Conjunto a diccionario:", diccionario)
# Out:
# 1. LISTA
# Lista original: ['gato', 'perro', 'loro', 'peces']
# Lista a tupla: ('gato', 'perro', 'loro', 'peces')
# Lista a diccionario: {0: 'gato', 1: 'perro', 2: 'loro', 3: 'peces'}
# Lista a conjunto: {'perro', 'gato', 'peces', 'loro'}
# 2. TUPLA
# Tupla original: ('h', 'o', 'l', 'a', ' ', 'p', 'r', 'o', 'f', 'e')
# Tupla a lista: ['h', 'o', 'l', 'a', ' ', 'p', 'r', 'o', 'f', 'e']
# Tupla a diccionario: {0: 'h', 1: 'o', 2: 'l', 3: 'a', 4: ' ', 5: 'p', 6: 'r', 7: 'o', 8: 'f', 9: 'e'}
# Tupla a conjunto: {'l', 'e', 'p', 'f', 'r', 'h', 'a', 'o', ' '}
# 3. DICCIONARIO
# Diccionario original: {'Nombre': 'Sergio', 'edad': '17', 'estatura': '1.68m', 'estudia': 'matematicas'}
# Diccionario a lista (claves): ['Nombre', 'edad', 'estatura', 'estudia']
# Diccionario a tupla: (('Nombre', 'Sergio'), ('edad', '17'), ('estatura', '1.68m'), ('estudia', 'matematicas'))
# Diccionario a conjunto: {('Nombre', 'Sergio'), ('edad', '17'), ('estatura', '1.68m'), ('estudia', 'matematicas')}
# 4. CONJUNTO
# ...
